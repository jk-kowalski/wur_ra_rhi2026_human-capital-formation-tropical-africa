# %%
# %pip install pandas

# %%
import pandas as pd

df = pd.read_stata(
    "C:/Users/kubak/Downloads/Africa_HC/Human capital/Data processing/tanzania_clean.dta",
    convert_categoricals=False
)

# %%
import pandas as pd

path = "C:/Users/kubak/Downloads/Africa_HC/Human capital/Data processing/tanzania_clean.dta"

df = pd.read_stata(path, convert_categoricals=False)

# %%
df.head()
# Out:
#    country  year     sample  serial  hhwt  subsamp  geolev1    geolev2  \
# 0      834  1988  834198801    1000  15.5       26   834001  834001001
# 1      834  1988  834198801    1000  15.5       26   834001  834001001
# 2      834  1988  834198801    2000  15.5       76   834001  834001001
# 3      834  1988  834198801    3000  15.5        2   834001  834001001
# 4      834  1988  834198801    3000  15.5        2   834001  834001001
#
#    popdensgeo1  popdensgeo2  ...   bpltz  birth_province  foreign  age  \
# 0        29.54        26.15  ...  dodoma        834001.0      0.0   29
# 1        29.54        26.15  ...   tanga        834004.0      0.0   35
# 2        29.54        26.15  ...  dodoma        834001.0      0.0   21
# 3        29.54        26.15  ...  dodoma        834001.0      0.0   34
# 4        29.54        26.15  ...  dodoma        834001.0      0.0   22
#
#    birth_year  cohort                  edattaind  educ  higher_educ  \
# ...

# %%
df.columns
# Out:
# Index(['country', 'year', 'sample', 'serial', 'hhwt', 'subsamp', 'geolev1',
#        'geolev2', 'popdensgeo1', 'popdensgeo2', 'areamollwgeo1',
#        'areamollwgeo2', 'geo1_tz', 'geo1_tz1988', 'geo1_tz2002', 'geo1_tz2012',
#        'geo2_tz', 'geo2_tz1988', 'geo2_tz2002', 'geo2_tz2012', 'dhs_ipumsi_tz',
#        'pernum', 'perwt', 'age2', 'sex', 'nativity', 'bplcountry', 'citizen',
#        'nation', 'school', 'lit', 'edattain', 'yrschool', 'eductz', 'empstat',
#        'empstatd', 'labforce', 'occisco', 'occ', 'indgen', 'ind', 'migrate1',
#        'migrate0', 'migctry1', 'migctry0', 'geomig1_1', 'geomig1_10',
#        'mig1_1_tz', 'mig1_10_tz', 'mig2_1_tz', 'bpltz', 'birth_province',
#        'foreign', 'age', 'birth_year', 'cohort', 'edattaind', 'educ',
#        'higher_educ', 'tertiary_educ'],
#       dtype='str')

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 4472164
# Columns: 60

# %%
df.info
# Out:
# <bound method DataFrame.info of          country  year     sample     serial   hhwt  subsamp  geolev1  \
# 0            834  1988  834198801       1000  15.50       26   834001
# 1            834  1988  834198801       1000  15.50       26   834001
# 2            834  1988  834198801       2000  15.50       76   834001
# 3            834  1988  834198801       3000  15.50        2   834001
# 4            834  1988  834198801       3000  15.50        2   834001
# ...          ...   ...        ...        ...    ...      ...      ...
# 4472159      834  2012  834201201  950775000   2.75       21   834055
# 4472160      834  2012  834201201  950776000   2.75       48   834055
# 4472161      834  2012  834201201  950776000   2.75       48   834055
# 4472162      834  2012  834201201  950776000   2.75       48   834055
# 4472163      834  2012  834201201  950776000   2.75       48   834055
#
#            geolev2  popdensgeo1  popdensgeo2  ...                       bpltz  \
# ...

# %%
df.head()
df.sample(5)
# Out:
#          country  year     sample     serial   hhwt  subsamp  geolev1  \
# 1062189      834  2002  834200201   31949000  13.59       93   834001
# 652470       834  1988  834198801  312903000   7.16        2   834014
# 4210741      834  2012  834201201  816772000   6.89       61   834002
# 1594114      834  2002  834200201  300805000   1.53       81   834002
# 3198215      834  2012  834201201  268562000  20.94        4   834006
#
#            geolev2  popdensgeo1  popdensgeo2  ...    bpltz  birth_province  \
# 1062189  834001001        39.97    32.750000  ...   dodoma        834001.0
# 652470   834014004        13.68     8.950000  ...   kagera        834019.0
# 4210741  834002008        37.12    11.630000  ...  manyara        834002.0
# 1594114  834002004        27.78    58.669998  ...  manyara        834002.0
# 3198215  834006002        33.12    66.449997  ...    mbeya        834012.0
#
#          foreign  age  birth_year  cohort                  edattaind  educ  \
# ...

# %%
df["year"].value_counts()
# Out:
# year
# 2012    1764250
# 2002    1706968
# 1988    1000946
# Name: count, dtype: int64

# %%
# %pip install pypandoc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pypandoc

def convert_docx_to_markdown(docx_path, markdown_path=None):
    """
    Convert a Word document (.docx) to Markdown using pypandoc.
    
    Args:
        docx_path (str): Path to the input .docx file
        markdown_path (str, optional): Path to the output .md file. 
                                      If None, uses the same name as input with .md extension
    
    Returns:
        str: Path to the generated Markdown file
    """
    # Ensure pandoc is installed
    pypandoc.ensure_pandoc_installed()
    
    if not os.path.exists(docx_path):
        raise FileNotFoundError(f"Input file not found: {docx_path}")
    
    if markdown_path is None:
        markdown_path = os.path.splitext(docx_path)[0] + '.md'
    
    # Use pypandoc to convert docx to markdown
    try:
        pypandoc.convert_file(docx_path, 'md', outputfile=markdown_path)
        
        print(f"Successfully converted {docx_path} to {markdown_path}")
        return markdown_path
        
    except Exception as e:
        print(f"Error converting file: {e}")
        raise

# Example usage:
# Set working directory to the project root
os.chdir(r"C:\Users\kubak\Documents\research_assistant_wur\research_assistant_rhi2026_africa")

convert_docx_to_markdown('rhi2026_africa_RA_documentation.docx', 'rhi2026_africa_RA_documentation.md')
# or
# convert_docx_to_markdown('input.docx')  # outputs to input.md
# Out:
# Successfully converted rhi2026_africa_RA_documentation.docx to rhi2026_africa_RA_documentation.md
# 'rhi2026_africa_RA_documentation.md'

# %% [markdown]
# # Convert .dat to csv

# %%
# %pip install --only-binary :all: pyarrow

# %pip install ipumspy
# Out:
# ...
#    ---------------------------------------- 0.0/28.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/28.2 MB ? eta -:--:--
#    ---- ----------------------------------- 3.1/28.2 MB 15.3 MB/s eta 0:00:02
#    --------- ------------------------------ 6.8/28.2 MB 16.2 MB/s eta 0:00:02
#    -------------- ------------------------- 10.2/28.2 MB 16.4 MB/s eta 0:00:02
#    ------------------- -------------------- 13.6/28.2 MB 16.6 MB/s eta 0:00:01
#    ------------------------ --------------- 17.0/28.2 MB 16.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 20.7/28.2 MB 16.7 MB/s eta 0:00:01
#    --------------------------------- ------ 23.9/28.2 MB 16.6 MB/s eta 0:00:01
#    -------------------------------------- - 27.3/28.2 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 28.2/28.2 MB 15.2 MB/s  0:00:02
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# ...

# %%
import ipumspy

ddi = ipumspy.read_ipums_ddi(r"C:\Users\kubak\Documents\research_assistant_wur\research_assistant_rhi2026_africa\1_inputs\15tanzania\ipumsi_00015.xml")
df = ipumspy.read_microdata(ddi, r"C:\Users\kubak\Documents\research_assistant_wur\research_assistant_rhi2026_africa\1_inputs\15tanzania\ipumsi_00015.dat\ipumsi_00015.dat")

df.to_csv("ipums.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import ipumspy
#       3 ddi = ipumspy.read_ipums_ddi(r"C:\Users\kubak\Documents\research_assistant_wur\research_assistant_rhi2026_africa\1_inputs\15tanzania\ipumsi_00015.xml")
#       4 df = ipumspy.read_microdata(ddi, r"C:\Users\kubak\Documents\research_assistant_wur\research_assistant_rhi2026_africa\1_inputs\15tanzania\ipumsi_00015.dat\ipumsi_00015.dat")
#
# ModuleNotFoundError: No module named 'ipumspy'
